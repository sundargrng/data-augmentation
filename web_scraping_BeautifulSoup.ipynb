# %%
import requests 
import os
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from PIL import Image
from io import BytesIO

# %%
url= "https://www.daraz.com.np/#?"
response= requests.get(url)
soup= BeautifulSoup(response.text,'html.parser')

img_tags= soup.find_all('img')

desktop_path = os.path.join(os.path.expanduser("~"), "Desktop", "images")
os.makedirs(desktop_path, exist_ok=True)

# %%
for img in img_tags:
    
    img_url = img.get('src')
    img_url = urljoin(url, img_url)
    
    img_response = requests.get(img_url)
    if img_response.status_code == 200:
        content_type = img_response.headers.get('Content-Type')
        if 'image' in content_type:
            try:
          
                img_data = Image.open(BytesIO(img_response.content))
                
             
                parsed_url = urlparse(img_url)
                img_name = os.path.join(desktop_path, os.path.basename(parsed_url.path))
                
               
                if not img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                    img_name += '.jpg' 
                
                img_data.save(img_name)
                print(f"Downloaded {img_name}")
            except Exception as e:
                print(f"Failed to process image {img_url}: {e}")
        else:
            print(f"URL does not point to an image: {img_url}")
    else:
        print(f"Failed to retrieve image. Status code: {img_response.status_code}")
# Out:
# Downloaded C:\Users\gurun\Desktop\images\O1CN01da6D0K1Khogk708ZP_!!6000000001196-0-tps-150-150.jpg
# Downloaded C:\Users\gurun\Desktop\images\3b870cb043c7f8a9741cbf66329e294e.png
# Downloaded C:\Users\gurun\Desktop\images\1f15fded-6656-4d4d-a8ec-64085fed1cd4_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\f3948b8a-22a5-40f8-b572-c481ac4f725d_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\9eb9c070-b209-4a24-a4bd-f8f3397d867c_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\06771c0d-adb9-4ee2-b22d-62151a94281f_NP-1976-688.png_2200x2200q80.png
# Downloaded C:\Users\gurun\Desktop\images\6dcb0c3e-e5b8-489d-aed1-9bd6c2a3e4af_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\4828aa46-c695-4977-abdc-ebb2655c198e_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\7d369935-9b65-46a2-93ec-d2c6452e6e64_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\0ab4bb6a-cfcd-4c88-8111-754f839e6df7_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\616f49fb-12bd-432a-a617-b2b934516d00_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\188102cd-508d-4e9d-bac1-fb43a0edfbf2_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\4e7bacde-acf2-45f7-b734-704cafac7c95_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\b576b427-3613-4f11-97e1-4bc83b92e8ce_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\d2c2bdae-0c23-4b8d-8a19-6d25c59e1c2c_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\61b053d9-9777-4077-b0d3-e2f07a07f6ff_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\1ee015d6a5c62fd0339c88c657c1c183.jpg_120x120q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\O1CN01cAMOjU1zqQJZU8EbT_!!6000000006765-2-tps-19-18.png_80x80q80.png
# Downloaded C:\Users\gurun\Desktop\images\O1CN01n3PMa828kJZVuCbPp_!!6000000007970-2-tps-72-72.png_150x150q80.png
# Downloaded C:\Users\gurun\Desktop\images\O1CN01J03SMW1lebTE7xkaN_!!6000000004844-2-tps-72-72.png_150x150q80.png
# Downloaded C:\Users\gurun\Desktop\images\O1CN01da6D0K1Khogk708ZP_!!6000000001196-0-tps-150-150.jpg_360x360q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\S208c05f65db642a6bd87ae9b0b317519X.jpg_400x400q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\95354f5d7f7b79bc5e016833edf6930f.jpg_400x400q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\c90f6525d68a07a094c5527570083a49.jpg_400x400q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\f1d2a94ce9c9f8555ac9fe14821e4720.jpg_400x400q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\a944b50df9492d39e5fb0d4923f74588.jpg_400x400q80.jpg
# Downloaded C:\Users\gurun\Desktop\images\6772b66b950ef751923bb190851cbb65.png_400x400q80.png
# Downloaded C:\Users\gurun\Desktop\images\d57b240d89fd69b1ccada2f04b58dc43.png_170x170q80.png
# Downloaded C:\Users\gurun\Desktop\images\2bbb54f5c63fd41501562f6f6902d271.jpg_170x170q80.jpg
# Downloaded C:\Users\gurun\Desktop\images